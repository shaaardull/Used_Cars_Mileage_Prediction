# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df = pd.read_csv("Cars_Data.csv")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df[["mpg","weight","year"]]
# Out:
#       mpg  weight  year
# 0    18.0    3504    70
# 1    15.0    3693    70
# 2    18.0    3436    70
# 3    16.0    3433    70
# 4    17.0    3449    70
# ..    ...     ...   ...
# 387  27.0    2790    82
# 388  44.0    2130    82
# 389  32.0    2295    82
# 390  28.0    2625    82
# 391  31.0    2720    82
#
# [392 rows x 3 columns]

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
df["name"].value_counts()
# Out:
# ford pinto                   5
# toyota corolla               5
# amc matador                  5
# toyota corona                4
# amc hornet                   4
#                             ..
# plymouth satellite custom    1
# ford torino                  1
# mercedes benz 300d           1
# plymouth custom suburb       1
# fiat 131                     1
# Name: name, Length: 301, dtype: int64

# %%
df["cylinders"].value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
df.isnull().count()
# Out:
# mpg             392
# cylinders       392
# displacement    392
# horsepower      392
# weight          392
# acceleration    392
# year            392
# origin          392
# name            392
# dtype: int64

# %%
pd.Series([np.nan]).sum()
# Out:
# 0.0

# %%
sns.regplot(x="mpg", y="acceleration", data=df)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='acceleration'>

# %%
sns.regplot(x="mpg", y="acceleration", data=df)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='acceleration'>

# %%
sns.boxplot(x="cylinders", y="displacement", data=df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration      year    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369855 -0.614535
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# ...

# %%
sns.regplot(x="mpg", y="displacement", data=df)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df['mpg'], df['weight'])
print("Pearson coefficient =",pearson_coef,"\n"+"p-value =",p_value)
# Out:
# Pearson coefficient = -0.8322442148315757
# p-value = 6.015296051433915e-102

# %%
pearson_coef, p_value = stats.pearsonr(df['mpg'], df['cylinders'])
print("Pearson coefficient =",pearson_coef,"\n"+"p-value =",p_value)
# Out:
# Pearson coefficient = -0.7776175081260257
# p-value = 1.3113836370957004e-80

# %%
pearson_coef, p_value = stats.pearsonr(df['mpg'], df['displacement'])
print("Pearson coefficient =",pearson_coef,"\n"+"p-value =",p_value)
# Out:
# Pearson coefficient = -0.8051269467104586
# p-value = 1.660641827796853e-90

# %%
pearson_coef, p_value = stats.pearsonr(df['mpg'], df['horsepower'])
print("Pearson coefficient =",pearson_coef,"\n"+"p-value =",p_value)
# Out:
# Pearson coefficient = -0.7784267838977775
# p-value = 7.031989029395957e-81

# %% [markdown]
# # Practice on groupby() begins here onwards.

# %%
grouped_bynames = df.groupby(["name"])
grouped_bynames

# %%
for name, names_df in grouped_bynames:
    print(name)
    print(names_df)
# Out:
# amc ambassador brougham
#      mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 95  13.0          8         360.0         175    3821          11.0    73
#
#     origin                     name
# 95       1  amc ambassador brougham
# amc ambassador dpl
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 9  15.0          8         390.0         190    3850           8.5    70
#
#    origin                name
# 9       1  amc ambassador dpl
# amc ambassador sst
#      mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 65  17.0          8         304.0         150    3672          11.5    72
#
#     origin                name
# 65       1  amc ambassador sst
# amc concord
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 255  19.4          6         232.0          90    3210          17.2    78
# 313  24.3          4         151.0          90    3003          20.1    80
#
# ...

# %%
grouped_bynames.mean()
# Out:
#                            mpg  cylinders  displacement  horsepower  weight  \
# name
# amc ambassador brougham  13.00        8.0         360.0       175.0  3821.0
# amc ambassador dpl       15.00        8.0         390.0       190.0  3850.0
# amc ambassador sst       17.00        8.0         304.0       150.0  3672.0
# amc concord              21.85        5.0         191.5        90.0  3106.5
# amc concord d/l          18.10        6.0         258.0       120.0  3410.0
# ...                        ...        ...           ...         ...     ...
# vw dasher (diesel)       43.40        4.0          90.0        48.0  2335.0
# vw pickup                44.00        4.0          97.0        52.0  2130.0
# vw rabbit                35.25        4.0          94.0        73.0  2040.5
# vw rabbit c (diesel)     44.30        4.0          90.0        48.0  2085.0
# vw rabbit custom         31.90        4.0          89.0        71.0  1925.0
#
# ...

# %%
grouped_bynames.sum()
# Out:
#                           mpg  cylinders  displacement  horsepower  weight  \
# name
# amc ambassador brougham  13.0          8         360.0         175    3821
# amc ambassador dpl       15.0          8         390.0         190    3850
# amc ambassador sst       17.0          8         304.0         150    3672
# amc concord              43.7         10         383.0         180    6213
# amc concord d/l          18.1          6         258.0         120    3410
# ...                       ...        ...           ...         ...     ...
# vw dasher (diesel)       43.4          4          90.0          48    2335
# vw pickup                44.0          4          97.0          52    2130
# vw rabbit                70.5          8         188.0         146    4081
# vw rabbit c (diesel)     44.3          4          90.0          48    2085
# vw rabbit custom         31.9          4          89.0          71    1925
#
#                          acceleration  year  origin
# name
# ...

# %% [markdown]
# #  ----------

# %%
df["sqrt_of_accln"] = df["acceleration"].apply(np.sqrt)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name  sqrt_of_accln
# 0       1  chevrolet chevelle malibu       3.464102
# 1       1          buick skylark 320       3.391165
# 2       1         plymouth satellite       3.316625
# 3       1              amc rebel sst       3.464102
# 4       1                ford torino       3.240370

# %%
df["disp*horsepower"] = df.apply(lambda x: x["displacement"]*x["horsepower"], axis = 1)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
# ...

# %% [markdown]
# # -----------

# %%
df = df.drop(["year","origin","acceleration","sqrt_of_accln","disp*horsepower"], axis = 1)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  \
# 0    18.0          8         307.0         130    3504
# 1    15.0          8         350.0         165    3693
# 2    18.0          8         318.0         150    3436
# 3    16.0          8         304.0         150    3433
# 4    17.0          8         302.0         140    3449
# ..    ...        ...           ...         ...     ...
# 387  27.0          4         140.0          86    2790
# 388  44.0          4          97.0          52    2130
# 389  32.0          4         135.0          84    2295
# 390  28.0          4         120.0          79    2625
# 391  31.0          4         119.0          82    2720
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# ...

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[["cylinders","displacement","horsepower","weight"]],df["mpg"])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-3.93285431e-01,  1.38893129e-04, -4.28124811e-02, -5.27717310e-03])

# %%
reg.intercept_
# Out:
# 45.75677052214771

# %% [markdown]
# # Let's predict mileage:

# %%
def predict_mpg(c,d,h,wt):
    predicted_mpg = reg.predict([[c,d,h,wt]])
    if predicted_mpg >= 0:
        return predicted_mpg
    else: print("Predicted mpg is equal to zero")

# %%
c = int(input("Enter number of cylinders: "))
d = float(input("Enter displacement in cc: "))
h = float(input("Enter horsepowers produced: "))
wt = float(input("Enter weight of the car: "))
predict_mpg(c,d,h,wt)
# Out:
# Enter number of cylinders: 3
# Enter displacement in cc: 1000
# Enter horsepowers produced: 120
# Enter weight of the car: 1.2
# array([39.57197701])
